# %% [markdown]
# ## Histogram Equalization

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

# %%
image=cv2.imread('images/giraffe-Kenya.png')
if image is None:
    print("Issue with image Loading")
else:
    print("Loading The Image Was Successfully")
# Out:
# Loading The Image Was Successfully

# %%
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray)

# %%
hist,bins=np.histogram(image_gray.flatten() , 256,[0,265])

## Perform histogram 
equalized_image=cv2.equalizeHist(image_gray)

equalized_hist,bins=np.histogram(equalized_image.flatten() , 256,[0,265])
## plot the result 
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
plt.imshow(image_gray , cmap='gray')
plt.title("Original Image")


plt.subplot(2,2,2)
plt.plot(hist , color='blue')
plt.title("Original Image")

plt.subplot(2,2,3)
plt.imshow(equalized_image , cmap='gray')
plt.title("equalized Image")

plt.subplot(2,2,4)
plt.plot(equalized_hist , color='green')
plt.title("Equalized  Image Histogram")

plt.tight_layout()
plt.show()

# %%
### YUV  ## TELEVISION

# %%
image_YUV=cv2.cvtColor(image,cv2.COLOR_BGR2YUV)

image_YUV[:,:,0]=cv2.equalizeHist(image_YUV[:,:,0]) ### only convert the Y part only  

equalized_color_image=cv2.cvtColor(image_YUV,cv2.COLOR_YUV2BGR)
equalized_color_image_RGB=cv2.cvtColor(equalized_color_image,cv2.COLOR_BGR2RGB)




## plot the result 
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
plt.imshow(image_rgb )
plt.title("Original Image")


plt.subplot(2,2,2)
plt.imshow(equalized_color_image_RGB)
plt.title("equalized_color_image_RGB")


plt.tight_layout()
plt.show()
